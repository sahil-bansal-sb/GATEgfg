# %%
print("Hi")
# Out:
# Hi

# %%
import requests

# %%
url = "https://www.geeksforgeeks.org/gate-cs-notes-gq/"
sorcecode = requests.get(url)

# %%
sorcecode.links
# Out:
# {}

# %%
sorcecode.text
# Out:
# '<!DOCTYPE html>\n<!--[if IE 7]>\n<html class="ie ie7" lang="en-US" prefix="og: http://ogp.me/ns#">\n<![endif]-->\n<!--[if IE 8]>\n<html class="ie ie8" lang="en-US" prefix="og: http://ogp.me/ns#">\n<![endif]-->\n<!--[if !(IE 7) | !(IE 8)  ]><!-->\n<html lang="en-US" prefix="og: http://ogp.me/ns#">\n<!--<![endif]-->\n<head>\n<meta charset="UTF-8" />\n<meta name="viewport" content="width=device-width" />\n<meta name="description" content="A Computer Science portal for geeks. It contains well written, well thought and well explained computer science and programming articles, quizzes and practice/competitive programming/company interview Questions.">\n<link rel="shortcut icon" href="/gfg.png" type="image/x-icon" />\n\n<meta name="theme-color" content="#4cb96b" />\n\n<meta property="og:image" content="https://www.geeksforgeeks.org/wp-content/uploads/gfg_200X200.png">\n<meta property="og:image:type" content="image/png">\n<meta property="og:image:width" content="200">\n<meta property="og:im
# ...

# %%
sorcecode.url
# Out:
# 'https://www.geeksforgeeks.org/gate-cs-notes-gq/'

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(sorcecode.text)

# %%
tableMain = soup.find('table')

# %%
subjects = dict()
for i in tableMain.findChildren('b'):
    if i.text.startswith('Section '):
        subjects[i.text.split(': ')[1]] = []

# %%
subjects.keys().__len__()
# Out:
# 10

# %%
for i in subjects:
    print(i, subjects[i])
# Out:
# Numerical and Verbal Ability  <ol>
# <li><b>Numerical Ability :</b>
# <ul>
# <li><a href="https://www.geeksforgeeks.org/placements-gq/">Placements</a></li>
# </ul>
# </li>
# <li><b>Verbal Ability  :</b>
# <ul>
# <li><a href="https://www.geeksforgeeks.org/placements-english-error-detection-correction/">Placements | English | Error Detection and Correction</a></li>
# <li><a href="https://www.geeksforgeeks.org/placements-english-passagesentence-re-arrangement/">Placements | English | Passage/Sentence Re-arrangement</a></li>
# <li><a href="https://www.geeksforgeeks.org/placements-english-fill-blanks/">Placements | English | Fill in the Blanks</a></li>
# <li><a href="https://www.geeksforgeeks.org/placements-english-comprehension-passages/">Placements | English | Comprehension Passages</a></li>
# </ul>
# </li>
# </ol>
# Algorithms <ol>
# <li><b>Discrete Mathematics :</b>
# <ul>
# ...

# %%
num = 0
keys = list(subjects.keys())
for i in tableMain.findChildren('tr')[1:]:
    subjects[keys[num]] = i.findChildren('td')[1].findChildren('ol')[0]
    num += 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-2be3c0579371> in <module>()
#       2 keys = list(subjects.keys())
#       3 for i in tableMain.findChildren('tr')[1:]:
# ----> 4     subjects[keys[num]] = i.findChildren('td')[1].findChildren('ol')[0]
#       5     num += 1
#
# IndexError: list index out of range

# %%
temp = subjects[list(subjects.keys())[0]]

# %%
temp.encode_contents
# Out:
# <bound method Tag.encode_contents of <ol>
# <li><b>Numerical Ability :</b>
# <ul>
# <li><a href="https://www.geeksforgeeks.org/placements-gq/">Placements</a></li>
# </ul>
# </li>
# <li><b>Verbal Ability  :</b>
# <ul>
# <li><a href="https://www.geeksforgeeks.org/placements-english-error-detection-correction/">Placements | English | Error Detection and Correction</a></li>
# <li><a href="https://www.geeksforgeeks.org/placements-english-passagesentence-re-arrangement/">Placements | English | Passage/Sentence Re-arrangement</a></li>
# <li><a href="https://www.geeksforgeeks.org/placements-english-fill-blanks/">Placements | English | Fill in the Blanks</a></li>
# <li><a href="https://www.geeksforgeeks.org/placements-english-comprehension-passages/">Placements | English | Comprehension Passages</a></li>
# </ul>
# </li>
# </ol>>

# %%
from formSideBar import subjectsMaker, getTable

# %%
tableMain = getTable()
# Out:
# /media/sahil/Complete/workstation/GATEgfg/formSideBar.py:8: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 8 of the file /media/sahil/Complete/workstation/GATEgfg/formSideBar.py. To get rid of this warning, pass the additional argument 'features="html5lib"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(sorcecode.text)

# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.geeksforgeeks.org/gate-cs-notes-gq/"
source = requests.get(url)
soup = BeautifulSoup(source.text)

# %%
import formSideBar

# %%
tableMain = formSideBar.get_table()
subjects = dict()
for i in tableMain.findChildren('tr')[1:]:
	for j in i.findChildren('td')[0].text.strip().split('\n'):
		if j.startswith('Section '):
			subjects[j.split(": ")[1]] = 0

# %%
for i in tableMain.findChildren('a'):
#     print(i.attrs['href'])
    if i.attrs['href'].find('geeksforgeeks.org') != -1:
        i.attrs['class'] = 'tarGet'
        print(i)
#         par = i.findParent()
#         par.clear()
# Out:
# <a class="tarGet" href="https://www.geeksforgeeks.org/placements-gq/">Placements</a>
# <a class="tarGet" href="https://www.geeksforgeeks.org/placements-english-error-detection-correction/">Placements | English | Error Detection and Correction</a>
# <a class="tarGet" href="https://www.geeksforgeeks.org/placements-english-passagesentence-re-arrangement/">Placements | English | Passage/Sentence Re-arrangement</a>
# <a class="tarGet" href="https://www.geeksforgeeks.org/placements-english-fill-blanks/">Placements | English | Fill in the Blanks</a>
# <a class="tarGet" href="https://www.geeksforgeeks.org/placements-english-comprehension-passages/">Placements | English | Comprehension Passages</a>
# <a class="tarGet" href="https://www.geeksforgeeks.org/placements-gq/">Placements</a>
# <a class="tarGet" href="https://www.geeksforgeeks.org/placements-gq/">Placements</a>
# ...

# %%
num = 0
keys = list(subjects.keys())
for i in tableMain.findChildren('tr')[1:]:
    subjects[keys[num]] = i.findChildren('td')[1].findChildren('ol')[0]
    # subjects[keys[num]] = str(subjects[keys[num]])
    num += 1

# %%
s = "ckasbcbkasckancasnckjnc ckasckaskcnaskcn kanc"

# %%
s.find('zxc')
# Out:
# -1

# %%
subjects = formSideBar.subjects_maker(0)

# %%
subjects
# Out:
# {'Numerical and Verbal Ability ': <ol>
#  <li><b>Numerical Ability :</b>
#  <ul>
#  <li><a class="tarGet" href="https://www.geeksforgeeks.org/placements-gq/">Placements</a></li>
#  </ul>
#  </li>
#  <li><b>Verbal Ability  :</b>
#  <ul>
#  <li><a class="tarGet" href="https://www.geeksforgeeks.org/placements-english-error-detection-correction/">Placements | English | Error Detection and Correction</a></li>
#  <li><a class="tarGet" href="https://www.geeksforgeeks.org/placements-english-passagesentence-re-arrangement/">Placements | English | Passage/Sentence Re-arrangement</a></li>
#  <li><a class="tarGet" href="https://www.geeksforgeeks.org/placements-english-fill-blanks/">Placements | English | Fill in the Blanks</a></li>
#  <li><a class="tarGet" href="https://www.geeksforgeeks.org/placements-english-comprehension-passages/">Placements | English | Comprehension Passages</a></li>
#  </ul>
#  </li>
#  </ol>, 'Mathematics ': <ol>
#  <li><b>Discrete Mathematics :</b>
#  <ul>
# ...

# %%
type(subjects[list(subjects.keys())[0]])
# Out:
# bs4.element.Tag

# %%
s = subjects[list(subjects.keys())[0]]

# %%
print(s.renderContents())
# Out:
# b'\n<li><b>Numerical Ability :</b>\n<ul>\n<li><a href="https://www.geeksforgeeks.org/placements-gq/">Placements</a></li>\n</ul>\n</li>\n<li><b>Verbal Ability  :</b>\n<ul>\n<li><a href="https://www.geeksforgeeks.org/placements-english-error-detection-correction/">Placements | English | Error Detection and Correction</a></li>\n<li><a href="https://www.geeksforgeeks.org/placements-english-passagesentence-re-arrangement/">Placements | English | Passage/Sentence Re-arrangement</a></li>\n<li><a href="https://www.geeksforgeeks.org/placements-english-fill-blanks/">Placements | English | Fill in the Blanks</a></li>\n<li><a href="https://www.geeksforgeeks.org/placements-english-comprehension-passages/">Placements | English | Comprehension Passages</a></li>\n</ul>\n</li>\n'

# %%
s.encode()
# Out:
# b'<ol>\n<li><b>Numerical Ability :</b>\n<ul>\n<li><a href="https://www.geeksforgeeks.org/placements-gq/">Placements</a></li>\n</ul>\n</li>\n<li><b>Verbal Ability  :</b>\n<ul>\n<li><a href="https://www.geeksforgeeks.org/placements-english-error-detection-correction/">Placements | English | Error Detection and Correction</a></li>\n<li><a href="https://www.geeksforgeeks.org/placements-english-passagesentence-re-arrangement/">Placements | English | Passage/Sentence Re-arrangement</a></li>\n<li><a href="https://www.geeksforgeeks.org/placements-english-fill-blanks/">Placements | English | Fill in the Blanks</a></li>\n<li><a href="https://www.geeksforgeeks.org/placements-english-comprehension-passages/">Placements | English | Comprehension Passages</a></li>\n</ul>\n</li>\n</ol>'

# %%
s
# Out:
# <ol>
# <li><b>Numerical Ability :</b>
# <ul>
# <li><a href="https://www.geeksforgeeks.org/placements-gq/">Placements</a></li>
# </ul>
# </li>
# <li><b>Verbal Ability  :</b>
# <ul>
# <li><a href="https://www.geeksforgeeks.org/placements-english-error-detection-correction/">Placements | English | Error Detection and Correction</a></li>
# <li><a href="https://www.geeksforgeeks.org/placements-english-passagesentence-re-arrangement/">Placements | English | Passage/Sentence Re-arrangement</a></li>
# <li><a href="https://www.geeksforgeeks.org/placements-english-fill-blanks/">Placements | English | Fill in the Blanks</a></li>
# <li><a href="https://www.geeksforgeeks.org/placements-english-comprehension-passages/">Placements | English | Comprehension Passages</a></li>
# </ul>
# </li>
# </ol>

# %%
a = subjects[list(subjects.keys())[0]]

# %%
a
# Out:
# <ol>
# <li><b>Numerical Ability :</b>
# <ul>
# <li><a href="https://www.geeksforgeeks.org/placements-gq/">Placements</a></li>
# </ul>
# </li>
# <li><b>Verbal Ability  :</b>
# <ul>
# <li><a href="https://www.geeksforgeeks.org/placements-english-error-detection-correction/">Placements | English | Error Detection and Correction</a></li>
# <li><a href="https://www.geeksforgeeks.org/placements-english-passagesentence-re-arrangement/">Placements | English | Passage/Sentence Re-arrangement</a></li>
# <li><a href="https://www.geeksforgeeks.org/placements-english-fill-blanks/">Placements | English | Fill in the Blanks</a></li>
# <li><a href="https://www.geeksforgeeks.org/placements-english-comprehension-passages/">Placements | English | Comprehension Passages</a></li>
# </ul>
# </li>
# </ol>

# %%
a.contents
# Out:
# ['\n', <li><b>Numerical Ability :</b>
#  <ul>
#  <li><a href="https://www.geeksforgeeks.org/placements-gq/">Placements</a></li>
#  </ul>
#  </li>, '\n', <li><b>Verbal Ability  :</b>
#  <ul>
#  <li><a href="https://www.geeksforgeeks.org/placements-english-error-detection-correction/">Placements | English | Error Detection and Correction</a></li>
#  <li><a href="https://www.geeksforgeeks.org/placements-english-passagesentence-re-arrangement/">Placements | English | Passage/Sentence Re-arrangement</a></li>
#  <li><a href="https://www.geeksforgeeks.org/placements-english-fill-blanks/">Placements | English | Fill in the Blanks</a></li>
#  <li><a href="https://www.geeksforgeeks.org/placements-english-comprehension-passages/">Placements | English | Comprehension Passages</a></li>
#  </ul>
#  </li>, '\n']

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-1f4a3badd4f4> in <module>()
# ----> 1 a.children()
#
# TypeError: 'list_iterator' object is not callable
